# %% [markdown]
# # Panda module practice

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# /Users/wentingpwt/miniforge3/lib/python3.9/site-packages/IPython/kernel/__init__.py:12: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   warn("The `IPython.kernel` package has been deprecated since IPython 4.0."
# /Users/wentingpwt/miniforge3/lib/python3.9/pkgutil.py:93: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# IPython             argparse            importlib           resource
# OpenSSL             array               importlib_metadata  rlcompleter
# PIL                 ast                 inspect             rmagic
# __future__          async_generator     io                  ruamel_yaml
# _abc                asynchat            ipaddress           runpy
# _aix_support        asyncio             ipykernel           sched
# ...

# %%
pf = pd.read_csv('card_transaction.csv')

# %%
mytuple = ("apple", "banana", "cherry")

# %%
type(mytuple)
# Out:
# tuple

# %%
type(pf.head(10).iterrows())
# Out:
# generator

# %%
# itterows() returns an iterator object (lable,content)
for i,row in pf.head(10).iterrows():
    print(i,row['Data_value'])
# Out:
# 0 2462.5
# 1 17177.2
# 2 22530.5
# 3 28005.1
# 4 30629.6
# 5 33317.4
# 6 36422.0
# 7 39198.0
# 8 40629.4
# 9 41815.4

# %%
for i,j in zip([1, 2, 3], ['sugar', 'spice', 'everything nice']):
    print(i,j)
# Out:
# 1 sugar
# 2 spice
# 3 everything nice

# %%
for item in zip([1, 2, 3], ['sugar', 'spice', 'everything nice']):
    print(item)
# Out:
# (1, 'sugar')
# (2, 'spice')
# (3, 'everything nice')

# %%
def cal_x2(x):
    return x*2

pf['Magnitude'].apply(cal_x2)
# Out:
# 0        12
# 1        12
# 2        12
# 3        12
# 4        12
#          ..
# 18451     0
# 18452     0
# 18453     0
# 18454     0
# 18455     0
# Name: Magnitude, Length: 18456, dtype: int64

# %%
pf.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0       ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars          6
# 1       ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars          6
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars          6
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars          6
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars          6
#
#                                          Subject  \
# 0  Electronic Card Transactions (ANZSIC06) - ECT
# 1  Electronic Card Transactions (ANZSIC06) - ECT
# 2  Electronic Card Transactions (ANZSIC06) - ECT
# 3  Electronic Card Transactions (ANZSIC06) - ECT
# 4  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                Group Series_title_1  \
# 0  Total values - Electronic card transactions A/...         Actual
# ...

# %%
pf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18456 entries, 0 to 18455
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  18456 non-null  object
#  1   Period            18456 non-null  float64
#  2   Data_value        16887 non-null  float64
#  3   Suppressed        448 non-null    object
#  4   STATUS            18456 non-null  object
#  5   UNITS             18456 non-null  object
#  6   Magnitude         18456 non-null  int64
#  7   Subject           18456 non-null  object
#  8   Group             18456 non-null  object
#  9   Series_title_1    18456 non-null  object
#  10  Series_title_2    18456 non-null  object
#  11  Series_title_3    3638 non-null   object
#  12  Series_title_4    0 non-null      float64
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.0+ MB

# %%
pf.describe(include=[np.number])
# Out:
#              Period    Data_value     Magnitude  Series_title_4  \
# count  18456.000000  1.688700e+04  18456.000000             0.0
# mean    2011.315068  1.543755e+07      4.207737             NaN
# std        6.008214  8.419977e+07      2.746230             NaN
# min     2000.010000 -5.130000e+01      0.000000             NaN
# 25%     2006.090000  1.764000e+02      0.000000             NaN
# 50%     2011.090000  1.172900e+03      6.000000             NaN
# 75%     2016.120000  4.225750e+03      6.000000             NaN
# max     2022.020000  1.874441e+09      6.000000             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
pf.describe(include=['O'])
# Out:
#        Series_reference Suppressed STATUS    UNITS  \
# count             18456        448  18456    18456
# unique              137          1      4        3
# top          ECTM.S4AWP          Y      R  Dollars
# freq                266        448   8538    13429
#
#                                               Subject  \
# count                                           18456
# unique                                              1
# top     Electronic Card Transactions (ANZSIC06) - ECT
# freq                                            18456
#
#                                                     Group Series_title_1  \
# count                                               18456          18456
# unique                                                  5              3
# top     Values - Electronic card transactions A/S/T by...         Actual
# freq                                                 7960           9464
#
#               Series_title_2  Series_title_3
# ...

# %%
ct=pf['Group'].value_counts()

# %%
type(ct)
# Out:
# pandas.core.series.Series

# %%
ct
# Out:
# Values - Electronic card transactions A/S/T by industry group            7960
# Total values - Electronic card transactions A/S/T by division            4983
# Number of electronic card transactions A/S/T by division                 1875
# Electronic card transactions by mean and proportion                      1832
# Totals - Electronic card transactions by division, percentage changes    1806
# Name: Group, dtype: int64

# %%
ct/len(pf.index)
# Out:
# Values - Electronic card transactions A/S/T by industry group            0.431296
# Total values - Electronic card transactions A/S/T by division            0.269993
# Number of electronic card transactions A/S/T by division                 0.101593
# Electronic card transactions by mean and proportion                      0.099263
# Totals - Electronic card transactions by division, percentage changes    0.097854
# Name: Group, dtype: float64

# %%
pf['Subject'].value_counts()
# Out:
# Electronic Card Transactions (ANZSIC06) - ECT    18456
# Name: Subject, dtype: int64

# %%
pf['Series_title_2'].value_counts()
# Out:
# RTS total industries                                           1972
# Total                                                          1972
# RTS core industries                                            1972
# Credit                                                         1374
# Debit                                                          1374
# Apparel                                                         995
# Non-retail excl. services                                       995
# Fuel                                                            995
# Motor vehicles excl. fuel                                       995
# Services                                                        995
# Hospitality                                                     995
# Durables                                                        995
# Consumables                                                     995
# Mean transaction value                                          376
# ...

# %%
pf['Series_title_3'].value_counts()
# Out:
# Proportion (%)                                      1236
# Percentage change from previous period               924
# Percentage change from same period previous year     882
# Value ($)                                            486
# Number                                               110
# Name: Series_title_3, dtype: int64

# %%
pf['Period'].value_counts()
# Out:
# 2004.03    137
# 2005.03    137
# 2006.03    137
# 2007.03    137
# 2008.03    137
#           ...
# 2001.05     23
# 2002.01     23
# 2001.07     23
# 2001.08     23
# 2001.11     23
# Name: Period, Length: 266, dtype: int64

# %%
pf.groupby('Period')['Group'].value_counts()
# Out:
# Period   Group
# 2000.01  Values - Electronic card transactions A/S/T by industry group             8
#          Electronic card transactions by mean and proportion                       5
#          Number of electronic card transactions A/S/T by division                  5
#          Total values - Electronic card transactions A/S/T by division             5
# 2000.02  Values - Electronic card transactions A/S/T by industry group             8
#                                                                                   ..
# 2022.02  Values - Electronic card transactions A/S/T by industry group            24
#          Total values - Electronic card transactions A/S/T by division            15
#          Totals - Electronic card transactions by division, percentage changes     6
#          Number of electronic card transactions A/S/T by division                  5
#          Electronic card transactions by mean and proportion                       3
# ...

# %%
pf[pf['Series_title_1']=='Actual'].groupby('Period')['Group'].value_counts()
# Out:
# Period   Group
# 2000.01  Values - Electronic card transactions A/S/T by industry group            8
#          Electronic card transactions by mean and proportion                      5
#          Number of electronic card transactions A/S/T by division                 5
#          Total values - Electronic card transactions A/S/T by division            5
# 2000.02  Values - Electronic card transactions A/S/T by industry group            8
#                                                                                  ..
# 2022.02  Values - Electronic card transactions A/S/T by industry group            8
#          Number of electronic card transactions A/S/T by division                 5
#          Total values - Electronic card transactions A/S/T by division            5
#          Electronic card transactions by mean and proportion                      3
#          Totals - Electronic card transactions by division, percentage changes    3
# ...

# %%
pf[(pf['Series_title_2']=='Total') & (pf['Series_title_3']=='Value ($)')].groupby('Period')['Group'].value_counts()
# Out:
# Series([], Name: Group, dtype: int64)

# %%
# Select subsets from the dataframe

# %%
pf.loc[pf['Series_title_2']=='Total','Series_title_3']
# Out:
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 46       NaN
#         ...
# 17659    NaN
# 17660    NaN
# 17661    NaN
# 17662    NaN
# 17663    NaN
# Name: Series_title_3, Length: 1972, dtype: object

# %%
pf.iloc[2:5,:5]
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS
# 2       ECTA.S19A1  2003.03     22530.5        NaN      F
# 3       ECTA.S19A1  2004.03     28005.1        NaN      F
# 4       ECTA.S19A1  2005.03     30629.6        NaN      F

# %%
pf_filtered=pf[(pf['Series_title_2']=='Total') & (pf['STATUS']=='F') & (pf['UNITS']=='Dollars')]

# %%
pf_filtered.groupby('Period')['Group'].value_counts()

# %%
#De-dup within a group

# %%
pf_grouped=pf_filtered.groupby('Period',as_index=False).nth(0)

# %%
pf_grouped['Period'].astype(str).sort_values()
# Out:
# 1539     2002.1
# 1540    2002.11
# 1541    2002.12
# 1542    2003.01
# 1543    2003.02
# 1544    2003.03
# 1545    2003.04
# 1546    2003.05
# 1547    2003.06
# 1548    2003.07
# 1549    2003.08
# 1550    2003.09
# 1551     2003.1
# 1552    2003.11
# 1553    2003.12
# 1554    2004.01
# 1555    2004.02
# 45      2004.03
# 1557    2004.04
# 1558    2004.05
# 1559    2004.06
# 1560    2004.07
# 1561    2004.08
# 1562    2004.09
# 1563     2004.1
# 1564    2004.11
# 1565    2004.12
# 1566    2005.01
# 1567    2005.02
# 46      2005.03
# 1569    2005.04
# 1570    2005.05
# 1571    2005.06
# 1572    2005.07
# 1573    2005.08
# 1574    2005.09
# 1575     2005.1
# 1576    2005.11
# 1577    2005.12
# 1578    2006.01
# 1579    2006.02
# 47      2006.03
# 1581    2006.04
# 1582    2006.05
# 1583    2006.06
# 1584    2006.07
# 1585    2006.08
# 1586    2006.09
# 1587     2006.1
# 1588    2006.11
# 1589    2006.12
# 1590    2007.01
# 1591    2007.02
# 48      2007.03
# 1593    2007.04
# ...

# %%
pd.set_option('display.max_rows', 500)

# %%
#pf_grouped['Period'].value_counts()

# %%
#pf_grouped.groupby('Period')['Data_value'].describe()

# %%
#pf_grouped

# %%
pf_grouped.plot(kind = 'scatter', x = 'Period', y = 'Data_value')
#plt.xticks('Period')
plt.tick_params(axis='x',width=3)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x_points=pf_grouped['Period']
x_str_points=str(x_points)
y_points=pf_grouped['Data_value']

# %%
pf_grouped
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 45         ECTA.S19A9  2004.03     36878.7        NaN      F  Dollars
# 46         ECTA.S19A9  2005.03     40756.2        NaN      F  Dollars
# 47         ECTA.S19A9  2006.03     44303.8        NaN      F  Dollars
# 48         ECTA.S19A9  2007.03     48616.7        NaN      F  Dollars
# 49         ECTA.S19A9  2008.03     52669.1        NaN      F  Dollars
# 50         ECTA.S19A9  2009.03     54475.5        NaN      F  Dollars
# 51         ECTA.S19A9  2010.03     55977.4        NaN      F  Dollars
# 52         ECTA.S19A9  2011.03     58624.9        NaN      F  Dollars
# 53         ECTA.S19A9  2012.03     62614.7        NaN      F  Dollars
# 54         ECTA.S19A9  2013.03     65296.1        NaN      F  Dollars
# 55         ECTA.S19A9  2014.03     69247.1        NaN      F  Dollars
# 56         ECTA.S19A9  2015.03     72320.3        NaN      F  Dollars
# ...

# %%
pf_grouped.groupby('Period')['Data_value'].mean()
# Out:
# Period
# 2002.10     2820.0
# 2002.11     2880.0
# 2002.12     3498.4
# 2003.01     2848.9
# 2003.02     2713.4
# 2003.03     2941.7
# 2003.04     2801.5
# 2003.05     2913.5
# 2003.06     2696.8
# 2003.07     2957.9
# 2003.08     2927.8
# 2003.09     2871.6
# 2003.10     3076.3
# 2003.11     3166.8
# 2003.12     3911.9
# 2004.01     3166.5
# 2004.02     3057.1
# 2004.03    36878.7
# 2004.04     3216.2
# 2004.05     3210.8
# 2004.06     3087.0
# 2004.07     3325.8
# 2004.08     3230.1
# 2004.09     3221.4
# 2004.10     3361.6
# 2004.11     3518.5
# 2004.12     4259.4
# 2005.01     3390.8
# 2005.02     3311.7
# 2005.03    40756.2
# 2005.04     3493.0
# 2005.05     3437.1
# 2005.06     3373.0
# 2005.07     3582.0
# 2005.08     3549.1
# 2005.09     3532.9
# 2005.10     3669.5
# 2005.11     3822.2
# 2005.12     4578.1
# 2006.01     3669.6
# 2006.02     3579.8
# 2006.03    44303.8
# 2006.04     3733.6
# 2006.05     3873.1
# 2006.06     3733.8
# 2006.07     3878.9
# 2006.08     3904.0
# ...

# %%
pf_grouped['value_cat']=np.where(pf_grouped['Data_value']>10000,1,0)
# Out:
# /var/folders/jb/ddnjd1q5001b22_dpttvzzvw0000gn/T/ipykernel_4998/3441246931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf_grouped['value_cat']=np.where(pf_grouped['Data_value']>10000,1,0)

# %%
pf_grouped[['Period','value_cat']]
# Out:
#        Period  value_cat
# 45    2004.03          1
# 46    2005.03          1
# 47    2006.03          1
# 48    2007.03          1
# 49    2008.03          1
# 50    2009.03          1
# 51    2010.03          1
# 52    2011.03          1
# 53    2012.03          1
# 54    2013.03          1
# 55    2014.03          1
# 56    2015.03          1
# 57    2016.03          1
# 58    2017.03          1
# 59    2018.03          1
# 60    2019.03          1
# 61    2020.03          1
# 62    2021.03          1
# 1539  2002.10          0
# 1540  2002.11          0
# 1541  2002.12          0
# 1542  2003.01          0
# 1543  2003.02          0
# 1544  2003.03          0
# 1545  2003.04          0
# 1546  2003.05          0
# 1547  2003.06          0
# 1548  2003.07          0
# 1549  2003.08          0
# 1550  2003.09          0
# 1551  2003.10          0
# 1552  2003.11          0
# 1553  2003.12          0
# 1554  2004.01          0
# 1555  2004.02          0
# 1557  2004.04          0
# ...

# %%
pf_grouped.loc[pf_grouped['value_cat']==1,'Period']
# Out:
# 45    2004.03
# 46    2005.03
# 47    2006.03
# 48    2007.03
# 49    2008.03
# 50    2009.03
# 51    2010.03
# 52    2011.03
# 53    2012.03
# 54    2013.03
# 55    2014.03
# 56    2015.03
# 57    2016.03
# 58    2017.03
# 59    2018.03
# 60    2019.03
# 61    2020.03
# 62    2021.03
# Name: Period, dtype: float64

# %%
pf_grouped['Magnitude'].describe()
# Out:
# count    233.0
# mean       6.0
# std        0.0
# min        6.0
# 25%        6.0
# 50%        6.0
# 75%        6.0
# max        6.0
# Name: Magnitude, dtype: float64

# %%
pd.crosstab(pf_grouped['value_cat'],pf_grouped['Magnitude'])
# Out:
# Magnitude    6
# value_cat
# 0          215
# 1           18

# %% [markdown]
# # Logistic Regression Practice

# %%
#Model evaluation metrics

# %%
# (1)Confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_true, y_pred)

#TP/FP/TN/FN

# %%
#(2)Classification Report
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, target_names=target_names))

#precision:  TP/(TP+FP)    - the proportion of true positives out of all captured 'positives' 
#recall - hit rate - sensitivity: TP/(TP+FN)  - the proportion of true positives that are captured out of all positives
#specificity: TN/(TN+FP)  - the proportion of true negatives that are catpured out of all negatives

# %%
#(3)Other measures
#ROC:  Y-sensitivity (pos%)/X-specificity (neg%)  ---AUROC
#Lorenze Curve: Y- cum pos% /X- cum Total%   ---GINI

#GINI = 2*AUROC - 1
